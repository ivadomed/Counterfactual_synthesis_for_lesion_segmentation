# %%
from torch.utils.data import Dataset
import torchio as tio
from monai.transforms import (
    Compose,
    RandSpatialCrop,
    RandShiftIntensity,
    RandRotate,
)
import os
from typing import Optional
import argparse
from pathlib import Path


PREPROCESSING_TRANSORMS = tio.Compose([
    tio.RescaleIntensity(out_min_max=(-1, 1)),

    # change here to the desired shape (/!\ must be powers of 2, GPU memory consuption is proportional to the size of the image)
    tio.CropOrPad(target_shape=(32, 256, 256))
])

# Since the training of the VQGAN is more memory intensive, one shall want to use smaller images
TRAIN_VQGAN_TRANSFORMS = Compose([
    RandSpatialCrop((16, 256, 256), random_size=False),
    RandShiftIntensity(offsets=0.1, prob=0.5),
    RandRotate(range_x=0.3, range_y=0.3, range_z=0.3, prob=0.5),
])

# For the DDPM training, we can use larger images since the decoding can be devided in several patches
TRAIN_DDPM_TRANSFORMS = Compose([
    RandShiftIntensity(offsets=0.1, prob=0.5),
    RandRotate(range_x=0.3, range_y=0.3, range_z=0.3, prob=0.5),
])


class BIDSDataset(Dataset):
    def __init__(self, root_dir: str, is_VQGAN: bool = False):
        super().__init__()
        root_dir = root_dir
        self.preprocessing = PREPROCESSING_TRANSORMS
        if is_VQGAN:
            self.transforms = TRAIN_VQGAN_TRANSFORMS
        else:
            self.transforms = TRAIN_DDPM_TRANSFORMS
        self.file_paths = self.get_data_files()

    def get_data_files(self):
        nifti_file_names = os.listdir(self.root_dir)
        folder_names = []
        for nifti_file_name in nifti_file_names:
            if nifti_file_name.endswith('.nii.gz'):
                folder_names.append(os.path.join(self.root_dir, nifti_file_name))
        print(f'Found {len(folder_names)} files in {self.root_dir}')
        return folder_names

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx: int): 
        img = tio.ScalarImage(self.file_paths[idx])
        img = self.preprocessing(img)
        img.data = self.transforms(img.data)
        return {'data': img.data}

# %%
import os

root_dir = "C:/Users/bapti/Documents/NeuroPoly/sci-paris"
folder_names = []
for root, dirs, files in os.walk(root_dir):
    print(root_dir +'/sub-')
    if root_dir +'/sub-' in root or root_dir +'\\sub_' in root:
        for file in files:
            if file.endswith('.nii.gz'):
                folder_names.append(os.path.join(root, file))
print(folder_names)
print(f'Found {len(folder_names)} files in {root_dir}')
# Out:
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# C:/Users/bapti/Documents/NeuroPoly/sci-paris/sub-
# ['C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-045\\anat\\sub-045_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-045\\anat\\sub-045_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-046\\anat\\sub-046_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-046\\anat\\sub-046_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-047\\anat\\sub-047_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-047\\anat\\sub-047_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-049\\anat\\sub-049_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-049\\anat\\sub-049_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-050\\anat\\sub-050_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-050\\anat\\sub-050_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-053\\anat\\sub-053_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-053\\anat\\sub-053_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-054\\anat\\sub-054_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-054\\anat\\sub-054_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-057\\anat\\sub-057_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-057\\anat\\sub-057_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-058\\anat\\sub-058_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-058\\anat\\sub-058_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-059\\anat\\sub-059_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-059\\anat\\sub-059_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-060\\anat\\sub-060_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-060\\anat\\sub-060_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-064\\anat\\sub-064_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-064\\anat\\sub-064_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-065\\anat\\sub-065_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-065\\anat\\sub-065_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-072\\anat\\sub-072_T2w_lesion-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\derivatives\\labels\\sub-072\\anat\\sub-072_T2w_seg-manual.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\sub-045\\anat\\sub-045_T2w.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\sub-046\\anat\\sub-046_T2w.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\sub-047\\anat\\sub-047_T2w.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\sub-049\\anat\\sub-049_T2w.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\sub-050\\anat\\sub-050_T2w.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\sub-053\\anat\\sub-053_T2w.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\sub-054\\anat\\sub-054_T2w.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\sub-057\\anat\\sub-057_T2w.nii.gz', 'C:/Users/bapti/Documents/NeuroPoly/sci-paris\\sub-058\\anat\\sub-058_T2w ...
# Found 42 files in C:/Users/bapti/Documents/NeuroPoly/sci-paris
